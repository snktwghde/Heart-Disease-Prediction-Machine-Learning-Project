# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("E:/Two Suns/heart_disease.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
#removing duplicates
df=df.drop_duplicates()
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# EDA

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
for col in df.columns[:-1]:        #take one column at a time, except the last one(target)
    sns.histplot(df[col],kde=True) #showing how values of that column are distributed, kde adding density curve
    plt.show()

# %%
#detecting outliers
plt.figure(figsize=(15,6))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df['chol'].describe()
# Out:
# count    302.000000
# mean     246.500000
# std       51.753489
# min      126.000000
# 25%      211.000000
# 50%      240.500000
# 75%      274.750000
# max      564.000000
# Name: chol, dtype: float64

# %%
df['trestbps'].describe()
# Out:
# count    302.000000
# mean     131.602649
# std       17.563394
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
cols=['chol','trestbps']
percentile_25=df[cols].quantile(0.25)
percentile_75=df[cols].quantile(0.75)

# %%
iqr=percentile_75-percentile_25
iqr
# Out:
# chol        63.75
# trestbps    20.00
# dtype: float64

# %%
upper_limit=percentile_75+1.5*iqr
lower_limit=percentile_25-1.5*iqr

# %%
print('upperlimit:',upper_limit)
print('lowerlimit:',lower_limit)
# Out:
# upperlimit: chol        370.375
# trestbps    170.000
# dtype: float64
# lowerlimit: chol        115.375
# trestbps     90.000
# dtype: float64

# %%
df[df['chol']>upper_limit['chol']]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 28    65    0   2       140   417    1        0      157      0      0.8
# 85    67    0   2       115   564    0        0      160      0      1.6
# 96    62    0   0       140   394    0        0      157      0      1.2
# 220   63    0   0       150   407    0        0      154      0      4.0
# 246   56    0   0       134   409    0        0      150      1      1.9
#
#      slope  ca  thal  target
# 28       2   1     2       1
# 85       1   0     3       1
# 96       1   0     2       1
# 220      1   3     3       0
# 246      1   2     3       0

# %%
df[df['chol']<lower_limit['chol']]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
df[df['trestbps']>upper_limit['trestbps']]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 8     52    1   2       172   199    1        1      162      0      0.5
# 101   59    1   3       178   270    0        0      145      0      4.2
# 110   64    0   0       180   325    0        1      154      1      0.0
# 203   68    1   2       180   274    1        0      150      1      1.6
# 223   56    0   0       200   288    1        0      133      1      4.0
# 241   59    0   0       174   249    0        1      143      1      0.0
# 248   54    1   1       192   283    0        0      195      0      0.0
# 260   66    0   0       178   228    1        1      165      1      1.0
# 266   55    0   0       180   327    0        2      117      1      3.4
#
#      slope  ca  thal  target
# 8        2   0     3       1
# 101      0   0     3       1
# 110      2   0     2       1
# 203      1   0     3       0
# 223      0   2     3       0
# 241      1   0     2       0
# ...

# %%
df[df['trestbps']<lower_limit['trestbps']]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
import numpy as np
df1 = df.copy()

df1[cols] = np.where(
    df1[cols] > upper_limit, upper_limit,
    np.where(
        df1[cols] < lower_limit, lower_limit,
        df1[cols]
    )
)
df1
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3     145.0  233.0    1        0      150      0      2.3
# 1     37    1   2     130.0  250.0    0        1      187      0      3.5
# 2     41    0   1     130.0  204.0    0        0      172      0      1.4
# 3     56    1   1     120.0  236.0    0        1      178      0      0.8
# 4     57    0   0     120.0  354.0    0        1      163      1      0.6
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 298   57    0   0     140.0  241.0    0        1      123      1      0.2
# 299   45    1   3     110.0  264.0    0        1      132      0      1.2
# 300   68    1   0     144.0  193.0    1        1      141      0      3.4
# 301   57    1   0     130.0  131.0    0        1      115      1      1.2
# 302   57    0   1     130.0  236.0    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %%
df1[cols].describe()
# Out:
#              chol    trestbps
# count  302.000000  302.000000
# mean   245.377070  131.258278
# std     47.486683   16.605232
# min    126.000000   94.000000
# 25%    211.000000  120.000000
# 50%    240.500000  130.000000
# 75%    274.750000  140.000000
# max    370.375000  170.000000

# %%
#outliers before and after
plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
sns.distplot(df['chol'])


plt.subplot(2,2,2)
sns.boxplot(x='chol',data=df)


plt.subplot(2,2,3)
sns.distplot(df1['chol'])


plt.subplot(2,2,4)
sns.boxplot(x='chol',data=df1)

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14352\185832111.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['chol'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14352\185832111.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['chol'])

# %%
#outliers before and after
plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
sns.distplot(df['trestbps'])


plt.subplot(2,2,2)
sns.boxplot(x='trestbps',data=df)


plt.subplot(2,2,3)
sns.distplot(df1['trestbps'])


plt.subplot(2,2,4)
sns.boxplot(x='trestbps',data=df1)

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14352\1996273172.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['trestbps'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14352\1996273172.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['trestbps'])

# %%
x=df.drop('target',axis=1)
y=df['target']

# %%
#train-test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(type(x_train))
print(x_train.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')

# %%
#scaling
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
num_cols = ['age', 'chol', 'trestbps', 'thalach']

x_train[num_cols] = scaler.fit_transform(x_train[num_cols])
x_test[num_cols] = scaler.transform(x_test[num_cols])

# %%
x_train
# Out:
#           age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 132  0.270833    1   1  0.245283  0.378753    0        1  0.649123      0
# 203  0.812500    1   2  0.811321  0.330254    1        0  0.543860      1
# 197  0.791667    1   0  0.292453  0.284065    1        1  0.657895      0
# 75   0.541667    0   1  0.386792  0.274827    0        0  0.640351      0
# 177  0.729167    1   2  0.433962  0.471132    0        1  0.614035      0
# ..        ...  ...  ..       ...       ...  ...      ...       ...    ...
# 189  0.250000    1   0  0.150943  0.094688    0        0  0.614035      0
# 71   0.458333    1   2  0.000000  0.221709    0        1  0.578947      1
# 106  0.833333    1   3  0.622642  0.237875    1        0  0.377193      0
# 271  0.666667    1   3  0.377358  0.237875    0        1  0.500000      0
# 102  0.708333    0   1  0.433962  0.147806    0        1  0.798246      0
#
#      oldpeak  slope  ca  thal
# 132      0.0      2   0     2
# ...

# %%
#model training
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,confusion_matrix,classification_report
lr=LogisticRegression(max_iter=2000,class_weight='balanced')
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=2000)

# %%
y_pred=lr.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8524590163934426

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85        29
#            1       0.90      0.81      0.85        32
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.86      0.85      0.85        61

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred1=dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.8032786885245902

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.90      0.81        29
#            1       0.88      0.72      0.79        32
#
#     accuracy                           0.80        61
#    macro avg       0.81      0.81      0.80        61
# weighted avg       0.82      0.80      0.80        61

# %%
rf = RandomForestClassifier(n_estimators=500,max_depth=None,class_weight='balanced',random_state=42)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=500,
#                        random_state=42)

# %%
y_pred2=rf.predict(x_test)

# %%
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        29
#            1       0.88      0.88      0.88        32
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61

# %%
gb = GradientBoostingClassifier(n_estimators=400,
    learning_rate=0.05,
    max_depth=3)
gb.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.05, n_estimators=400)

# %%
y_pred3=gb.predict(x_test)

# %%
print(classification_report(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84        29
#            1       0.89      0.78      0.83        32
#
#     accuracy                           0.84        61
#    macro avg       0.84      0.84      0.84        61
# weighted avg       0.84      0.84      0.84        61

# %%
xgb=XGBClassifier(n_estimators=100,learning_rate=0.1,max_depth=4,
    subsample=0.9,
    colsample_bytree=0.8,
    eval_metric='logloss')
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred4=xgb.predict(x_test)

# %%
print(classification_report(y_test,y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85        29
#            1       0.87      0.84      0.86        32
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61

# %%
#comparing models
models = {
    "LogReg": lr,
    "DecisionTree":dt,
    "RandomForest": rf,
    "GradientBoost": gb,
    "XGB": xgb,
}
results = {}

for name, model in models.items():
    y_pred = model.predict(x_test)
    results[name] = accuracy_score(y_test, y_pred)

results
# Out:
# {'LogReg': 0.8524590163934426,
#  'DecisionTree': 0.8032786885245902,
#  'RandomForest': 0.8688524590163934,
#  'GradientBoost': 0.8360655737704918,
#  'XGB': 0.8524590163934426}
